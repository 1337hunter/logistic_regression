# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/dataset_train.csv").drop(columns=[
                                        'Index',
                                        'First Name',
                                        'Last Name',
                                        'Birthday',
                                        'Best Hand',
                                        'Hogwarts House'])

# %%
plot = pd.plotting.scatter_matrix(df, figsize=(30,18), diagonal='kde', s=20, c='black',
                                                 linewidth=1)

# %%
sns.scatterplot(x=df['Astronomy'], y=df['Defense Against the Dark Arts'])
# Out:
# <AxesSubplot:xlabel='Astronomy', ylabel='Defense Against the Dark Arts'>
